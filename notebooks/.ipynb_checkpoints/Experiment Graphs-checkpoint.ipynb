# %% [markdown]
# # START: Experiment related Graphs

# %%
from fastread import Fastread 
from colour import Color
import sklearn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.cluster as cluster
import time
from math import cos, asin, sqrt
import copy, math
import ast 
from IPython.core.display import display, HTML
import random
# Out:
# /var/folders/vh/vq38xths5q9c0_2rkctq370w0000gn/T/ipykernel_78714/1243570097.py:14: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
# %matplotlib inline

# %% [markdown]
# # Define data parameters

# %%
city='bristol'
optimum_walking_distances = ['5','10','15','20','30','45']  
experiment_run_for = ['all_on',
                      'all_off',
                      'probability_only',
                      'weather_only',
                      'rating_only',
                      'no_of_tags_only',
                      'popular_time_only',
                      'travel_distance_only',
                      'opennes_only']

# %% [markdown]
# # Load data

# %%
experiment_data={param:dict() for param in experiment_run_for}
for experiment_parameter in experiment_run_for:
    for owd in optimum_walking_distances:
        experiment_file_name=str(experiment_parameter+'_'+owd)
        ff = Fastread('../evaluation/'+city+'/'+experiment_file_name)
        lines = ff.lines()
        pareto_lines=list()

        for i,line in enumerate(lines): 
            pareto_lines.append(ast.literal_eval(str(line)))
        experiment_data[experiment_parameter][owd]=pareto_lines

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Num of POI categorised

# %%
ff = Fastread('../datasets/'+city+'/routes_google_nodes_converted_with_visit_times')
lines = ff.lines()
 
poi_lines=[]
lens=[]
for line in lines:
    p_line=ast.literal_eval(str(line))
    poi_lines.append(p_line)
    lens.append(len(p_line['gmap_node_ids']))
       
labels = list(set(lens))

poi_cats={label:0 for label in labels}

for p_line in poi_lines: 
        poi_cats[len(p_line['gmap_node_ids'])]+=1

fig, ax = plt.subplots() 
y_pos = np.arange(len(labels)) 

ax.barh(y_pos, poi_cats.values(),  align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(labels)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Occurance',fontsize=20)
ax.set_ylabel('Number of POI in Route',fontsize=20)
ax.set_title('Density of number of routes',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

ax.set_xticks(np.arange(0, 21, step=1)) #  this is for bristol ds
plt.show()

# %% [markdown]
# ## POI distance histogram

# %%
with open('../datasets/'+city+'/distance_matrix') as f:
    dm = f.readlines()
matrix = [ast.literal_eval(item) for item in dm]

distances=[]
processed=[]

groups=set()
for k,v in matrix[0].items():
    processed.append(k)
    for nid,tp in v.items():
        if nid in processed :
            continue
        else:            
            distances.append(tp[1])
            if tp[1]<100:
                groups.add(k)
                groups.add(nid) 

distances.sort()
distances=[dist for dist in distances if dist < 10000 ]

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':300})

# Plot Histogram on x 
plt.hist(distances, bins=103)
plt.gca().set(title='Frequency Histogram of distance between POIS', ylabel='Frequency',xlabel='Meters');

# %%
type(distances)
# Out:
# list

# %% [markdown]
# # NDCG VS JACCARD pareto graphs for all experiments

# %%
# colour function for the graph below
def get_colour(owd):
    if owd =='5':
        return 'orange'
    elif owd == '10':
        return 'blue'
    elif owd == '15':
        return 'green'
    elif owd == '20':
        return 'gold'
    elif owd == '30':
        return 'purple'
    elif owd == '45':
        return 'red'

# %%
fig, axs = plt.subplots(9, 6)
 
for ex_index,experiment_parameter in enumerate(experiment_run_for):
    for owd_index,owd in enumerate(optimum_walking_distances):
        ndcg_list=[]
        jaccard_list=[]
        for experiment_result in experiment_data[experiment_parameter][owd]:
            ndcg_list.append(experiment_result['best_ndcg'])
            jaccard_list.append(experiment_result['best_jaccard'])
            
            axs[ex_index, owd_index].scatter(jaccard_list, ndcg_list, c=get_colour(owd),edgecolors='none',marker='o')
            if experiment_parameter == 'all_on':
                axs[ex_index, owd_index].set_title(owd+' Minutes')
                
plt.figure(figsize=(105, 130), dpi= 200)
plt.rcParams['figure.figsize'] = [20, 20]  

for ax in axs.flat:
    
    ax.set(xlabel='JACCARD', ylabel='NDCG')
    #ax.set_xticks(np.arange(0, 1.1, step=0.1))  
    #ax.set_yticks(np.arange(0, 1.1, step=0.1))
    # PS: change steeps to 0.2 for Bristol

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# # Legal and Illegal routes Stat

# %%
ff = Fastread('../datasets/'+city+'/routes_google_nodes_converted_with_visit_times')
lines = ff.lines()
pareto_lines=list()

for i,line in enumerate(lines): 
    pareto_lines.append(ast.literal_eval(str(line)))

# %%
owd_dict={owd:0 for owd in optimum_walking_distances}
total=len(pareto_lines)

for i,route_line in enumerate(pareto_lines):
    for minute,val in route_line['is_legal_dict'].items(): 
        owd_dict[str(minute)]+=val
        
for k,v in owd_dict.items():
    owd_dict[k]=math.ceil((v/total)*100)

owd_x=list(owd_dict.keys())
owd_legal=list(owd_dict.values())
owd_illegal=[100-val for val in owd_legal]

# %%
fig = plt.figure(figsize=(6,5), dpi=200)
left, bottom, width, height = 0.1, 0.3, 0.8, 0.6
ax = fig.add_axes([left, bottom, width, height]) 
 
width = 0.35   
ticks = np.arange(len(owd_x))   


ax.bar(ticks, owd_legal, width, label='Legal')
ax.bar(ticks + width, owd_illegal, width, align="center", label='Illegal')

ax.set_ylabel('Percantage of legal route')
ax.set_title('Distribution of Legal-Illegal routes')
ax.set_xticks(ticks + width/2)
plt.xticks(rotation=90)
 
ax.set_xticklabels(owd_x)
 
ax.legend(loc='best')
plt.show()

# %% [markdown]
# # Average ndcg and jaccard

# %%
experiment_data['opennes_only']
# Out:
# {'5': [{'user_id': '16669082@N05',
#    'route_index': 6,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 14,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 1, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Nelson Street',
#     'The Galleries',
#     "The New Room / John Wesley's Chapel"],
#    'best_route_names': ['Nelson Street', 'St Nicholas Market', 'Queen Square'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.99816961561928},
#   {'user_id': '65548708@N03',
#    'route_index': 9,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 28,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Bristol Cathedral',
#     'Park Street',
#     'Bristol Feeder Canal'],
#    'best_route_names': ['Bristol Cathedral', 'Bristol Aquarium', 'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.8901875509649361},
#   {'user_id': '67693615@N04',
#    'route_index': 11,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 27,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Galleries',
#     'The Bearpit',
#     "The New Room / John Wesley's Chapel"],
#    'best_route_names': ['The Galleries',
#     'St Nicholas Market',
#     'Queen Square',
#     'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7271727172717272},
#   {'user_id': '42801288@N05',
#    'route_index': 12,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 25,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['St Nicholas Market',
#     'M Shed',
#     'Arnolfini',
#     'College Green',
#     "Brunel's SS Great Britain"],
#    'best_route_names': ['St Nicholas Market',
#     'Castle Park',
#     "The New Room / John Wesley's Chapel"],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.8068548387096774},
#   {'user_id': '144974330@N06',
#    'route_index': 17,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 13,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 1, 30: 1, 20: 1, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ["St Peter's Church",
#     'The Galleries',
#     "The New Room / John Wesley's Chapel"],
#    'best_route_names': ["St Peter's Church",
#     'St Nicholas Market',
#     'Queen Square'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 2.026608910891089},
#   {'user_id': '88895568@N07',
#    'route_index': 32,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 29,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Nelson Street',
#     'Christmas Steps',
#     'The Centre, Bristol',
#     'Bristol Feeder Canal',
#     'St Mary Redcliffe Church',
#     "Pero's Bridge",
#     'The Bearpit',
#     "The New Room / John Wesley's Chapel",
#     'The Harbourside Market'],
#    'best_route_names': ['Nelson Street',
#     'St Nicholas Market',
#     'Queen Square',
#     'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7844539818788746},
#   {'user_id': '139879813@N08',
#    'route_index': 34,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 30,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 1, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Bearpit',
#     'Nelson Street',
#     'Tobacco Factory',
#     'Underfall Yard',
#     'The Centre, Bristol'],
#    'best_route_names': ['The Bearpit',
#     'Castle Park',
#     'St Nicholas Market',
#     'Queen Square',
#     'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7493167324627998},
#   {'user_id': '22619955@N06',
#    'route_index': 37,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 15,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 1, 30: 1, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['St Mary Redcliffe Church',
#     'Bristol Feeder Canal',
#     'Victoria Park',
#     'Puzzlair - 4D - Room Escape Games',
#     'St George Park',
#     'Troopers Hill'],
#    'best_route_names': ['St Mary Redcliffe Church', 'Queen Square', 'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.9288399944297452},
#   {'user_id': '32167019@N00',
#    'route_index': 40,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 29,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Christmas Steps',
#     'St Mary Redcliffe Church',
#     'The Centre, Bristol',
#     'Floating Harbour',
#     'Underfall Yard',
#     'M Shed'],
#    'best_route_names': ['Christmas Steps',
#     'St Nicholas Market',
#     'Castle Park',
#     "The New Room / John Wesley's Chapel"],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.0387198735677599},
#   {'user_id': '97888609@N02',
#    'route_index': 51,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 20,
#    'optimum_walking_time': '5',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Bearpit',
#     'College Green',
#     "Pero's Bridge",
#     'Bristol Feeder Canal'],
#    'best_route_names': ['The Bearpit',
#     'Castle Park',
#     'St Nicholas Market',
#     'Queen Square',
#     'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7979371396085438}],
#  '10': [{'user_id': '32440742@N04',
#    'route_index': 8,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 5,
#    'optimum_walking_time': '10',
#    'is_legal_dict': {45: 1, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Puzzlair - 4D - Room Escape Games',
#     'M Shed',
#     'Spike Island'],
#    'best_route_names': ['Puzzlair - 4D - Room Escape Games',
#     'Castle Park',
#     'Queen Square'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 2.1335504885993486},
#   {'user_id': '67693615@N04',
#    'route_index': 11,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 76,
#    'optimum_walking_time': '10',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Galleries',
#     'The Bearpit',
#     "The New Room / John Wesley's Chapel"],
#    'best_route_names': ['The Galleries', 'St Nicholas Market', 'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7271727172717272},
#   {'user_id': '62548071@N02',
#    'route_index': 29,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 276,
#    'optimum_walking_time': '10',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Spike Island',
#     'Clifton Lido and The Victoria Public House',
#     'Avon Gorge',
#     'Clifton Observatory'],
#    'best_route_names': ['Spike Island',
#     "Brunel's SS Great Britain",
#     'Arnolfini'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.35566316922249125},
#   {'user_id': '35163274@N05',
#    'route_index': 31,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 131,
#    'optimum_walking_time': '10',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Old Market Street',
#     'Floating Harbour',
#     'M Shed',
#     'Rainbow Casino Bristol'],
#    'best_route_names': ['Old Market Street', 'St Nicholas Market', 'M Shed'],
#    'best_ndcg': 0.26499301486112564,
#    'best_jaccard': 0.25,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.196627197703624},
#   {'user_id': '139879813@N08',
#    'route_index': 34,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 187,
#    'optimum_walking_time': '10',
#    'is_legal_dict': {45: 1, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Bearpit',
#     'Nelson Street',
#     'Tobacco Factory',
#     'Underfall Yard',
#     'The Centre, Bristol'],
#    'best_route_names': ['The Bearpit', 'St Nicholas Market', 'M Shed'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7493167324627998},
#   {'user_id': '39918296@N03',
#    'route_index': 42,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 6,
#    'optimum_walking_time': '10',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Clifton Down',
#     'Clifton Observatory',
#     'Durdham Downs'],
#    'best_route_names': ['Clifton Down',
#     'Bristol Zoo Gardens',
#     'Clifton Observatory'],
#    'best_ndcg': 0.23981246656813146,
#    'best_jaccard': 0.3333333333333333,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.2371808548467392}],
#  '15': [{'user_id': '20342758@N00',
#    'route_index': 2,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 142,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Cabot Tower',
#     'Millennium Square',
#     'Floating Harbour',
#     'Rainbow Casino Bristol',
#     "Brunel's SS Great Britain",
#     'Bristol Cathedral',
#     'Redcliffe Caves',
#     'The Harbourside Market',
#     'The Centre, Bristol',
#     'Park Street',
#     'Wills Memorial Building Tower',
#     'University of Bristol Theatre Collection',
#     'M Shed'],
#    'best_route_names': ['Cabot Tower',
#     "Brunel's SS Great Britain",
#     'St Mary Redcliffe Church'],
#    'best_ndcg': 0.1002975025250896,
#    'best_jaccard': 0.07692307692307693,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.4602765280368704},
#   {'user_id': '42801288@N05',
#    'route_index': 12,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 53,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['St Nicholas Market',
#     'M Shed',
#     'Arnolfini',
#     'College Green',
#     "Brunel's SS Great Britain"],
#    'best_route_names': ['St Nicholas Market',
#     "Brunel's SS Great Britain",
#     'Floating Harbour'],
#    'best_ndcg': 0.5461894817257589,
#    'best_jaccard': 0.2,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.8068548387096774},
#   {'user_id': '62548071@N02',
#    'route_index': 29,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 204,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Spike Island',
#     'Clifton Lido and The Victoria Public House',
#     'Avon Gorge',
#     'Clifton Observatory'],
#    'best_route_names': ['Spike Island',
#     "Brunel's SS Great Britain",
#     'Bristol Museum & Art Gallery'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.35566316922249125},
#   {'user_id': '95209750@N05',
#    'route_index': 33,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 96,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The corn exchange',
#     'New Room',
#     'Nelson Street',
#     'The Harbourside Market'],
#    'best_route_names': ['The corn exchange',
#     "Brunel's SS Great Britain",
#     'Windmill Hill City Farm'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.4784601950225586},
#   {'user_id': '20829994@N04',
#    'route_index': 38,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 62,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Being Brunel',
#     "Brunel's SS Great Britain",
#     'Avon Wildlife Trust',
#     'Bristol Aquarium'],
#    'best_route_names': ['Being Brunel',
#     "Brunel's SS Great Britain",
#     'Victoria Rooms'],
#    'best_ndcg': 0.21000199575396408,
#    'best_jaccard': 0.25,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.22879177377892032},
#   {'user_id': '32167019@N00',
#    'route_index': 40,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 59,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Christmas Steps',
#     'St Mary Redcliffe Church',
#     'The Centre, Bristol',
#     'Floating Harbour',
#     'Underfall Yard',
#     'M Shed'],
#    'best_route_names': ['Christmas Steps',
#     "Brunel's SS Great Britain",
#     'Upfest Gallery'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.0387198735677599},
#   {'user_id': '39918296@N03',
#    'route_index': 42,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 11,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Clifton Down',
#     'Clifton Observatory',
#     'Durdham Downs'],
#    'best_route_names': ['Clifton Down',
#     'Bristol Zoo Gardens',
#     'The Clifton Suspension Bridge'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.2371808548467392},
#   {'user_id': '143401526@N02',
#    'route_index': 46,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 131,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Being Brunel',
#     'Bristol Ferry Boats',
#     'Millennium Square'],
#    'best_route_names': ['Being Brunel',
#     "Brunel's SS Great Britain",
#     'Victoria Rooms'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.2933740191804708},
#   {'user_id': '21683597@N08',
#    'route_index': 48,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 62,
#    'optimum_walking_time': '15',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Millennium Square',
#     'Rainbow Casino Bristol',
#     'Bristol Cathedral',
#     'Llandoger Trow'],
#    'best_route_names': ['Millennium Square',
#     "Brunel's SS Great Britain",
#     'Tobacco Factory'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.5793450881612091}],
#  '20': [{'user_id': '20342758@N00',
#    'route_index': 2,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 209,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Cabot Tower',
#     'Millennium Square',
#     'Floating Harbour',
#     'Rainbow Casino Bristol',
#     "Brunel's SS Great Britain",
#     'Bristol Cathedral',
#     'Redcliffe Caves',
#     'The Harbourside Market',
#     'The Centre, Bristol',
#     'Park Street',
#     'Wills Memorial Building Tower',
#     'University of Bristol Theatre Collection',
#     'M Shed'],
#    'best_route_names': ['Cabot Tower',
#     "Brunel's SS Great Britain",
#     'Windmill Hill City Farm'],
#    'best_ndcg': 0.1002975025250896,
#    'best_jaccard': 0.07692307692307693,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.4602765280368704},
#   {'user_id': '86569608@N00',
#    'route_index': 10,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 30,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Castle Park', 'St Nicholas Market', 'King Street'],
#    'best_route_names': ['Castle Park',
#     "Brunel's SS Great Britain",
#     'Tobacco Factory'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.23904382470119523},
#   {'user_id': '42801288@N05',
#    'route_index': 12,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 46,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['St Nicholas Market',
#     'M Shed',
#     'Arnolfini',
#     'College Green',
#     "Brunel's SS Great Britain"],
#    'best_route_names': ['St Nicholas Market',
#     "Brunel's SS Great Britain",
#     'Tobacco Factory'],
#    'best_ndcg': 0.5461894817257589,
#    'best_jaccard': 0.2,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.8068548387096774},
#   {'user_id': '62548071@N02',
#    'route_index': 29,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 198,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Spike Island',
#     'Clifton Lido and The Victoria Public House',
#     'Avon Gorge',
#     'Clifton Observatory'],
#    'best_route_names': ['Spike Island',
#     "Brunel's SS Great Britain",
#     'Clifton Cathedral Church of Ss Peter and Paul'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.35566316922249125},
#   {'user_id': '88895568@N07',
#    'route_index': 32,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 358,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Nelson Street',
#     'Christmas Steps',
#     'The Centre, Bristol',
#     'Bristol Feeder Canal',
#     'St Mary Redcliffe Church',
#     "Pero's Bridge",
#     'The Bearpit',
#     "The New Room / John Wesley's Chapel",
#     'The Harbourside Market'],
#    'best_route_names': ['Nelson Street',
#     "Brunel's SS Great Britain",
#     'Upfest Gallery',
#     'Victoria Park',
#     'St Nicholas Market'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7844539818788746},
#   {'user_id': '95209750@N05',
#    'route_index': 33,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 163,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The corn exchange',
#     'New Room',
#     'Nelson Street',
#     'The Harbourside Market'],
#    'best_route_names': ['The corn exchange',
#     "Brunel's SS Great Britain",
#     'Upfest Gallery'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.4784601950225586},
#   {'user_id': '139879813@N08',
#    'route_index': 34,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 183,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 1, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Bearpit',
#     'Nelson Street',
#     'Tobacco Factory',
#     'Underfall Yard',
#     'The Centre, Bristol'],
#    'best_route_names': ['The Bearpit',
#     "Brunel's SS Great Britain",
#     'Upfest Gallery'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7493167324627998},
#   {'user_id': '20829994@N04',
#    'route_index': 38,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 76,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Being Brunel',
#     "Brunel's SS Great Britain",
#     'Avon Wildlife Trust',
#     'Bristol Aquarium'],
#    'best_route_names': ['Being Brunel',
#     "Brunel's SS Great Britain",
#     'Clifton Cathedral Church of Ss Peter and Paul'],
#    'best_ndcg': 0.21000199575396408,
#    'best_jaccard': 0.25,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.22879177377892032},
#   {'user_id': '32167019@N00',
#    'route_index': 40,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 150,
#    'optimum_walking_time': '20',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Christmas Steps',
#     'St Mary Redcliffe Church',
#     'The Centre, Bristol',
#     'Floating Harbour',
#     'Underfall Yard',
#     'M Shed'],
#    'best_route_names': ['Christmas Steps',
#     "Brunel's SS Great Britain",
#     'Tobacco Factory'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.0387198735677599}],
#  '30': [{'user_id': '86569608@N00',
#    'route_index': 10,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 34,
#    'optimum_walking_time': '30',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Castle Park', 'St Nicholas Market', 'King Street'],
#    'best_route_names': ['Castle Park',
#     "Brunel's SS Great Britain",
#     'Bristol Zoo Gardens'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.23904382470119523},
#   {'user_id': '42801288@N05',
#    'route_index': 12,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 61,
#    'optimum_walking_time': '30',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['St Nicholas Market',
#     'M Shed',
#     'Arnolfini',
#     'College Green',
#     "Brunel's SS Great Britain"],
#    'best_route_names': ['St Nicholas Market',
#     "Brunel's SS Great Britain",
#     'Ashton Court Estate'],
#    'best_ndcg': 0.5461894817257589,
#    'best_jaccard': 0.2,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.8068548387096774},
#   {'user_id': '88895568@N07',
#    'route_index': 32,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 221,
#    'optimum_walking_time': '30',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Nelson Street',
#     'Christmas Steps',
#     'The Centre, Bristol',
#     'Bristol Feeder Canal',
#     'St Mary Redcliffe Church',
#     "Pero's Bridge",
#     'The Bearpit',
#     "The New Room / John Wesley's Chapel",
#     'The Harbourside Market'],
#    'best_route_names': ['Nelson Street',
#     "Brunel's SS Great Britain",
#     'The Clifton Suspension Bridge'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7844539818788746},
#   {'user_id': '95209750@N05',
#    'route_index': 33,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 110,
#    'optimum_walking_time': '30',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The corn exchange',
#     'New Room',
#     'Nelson Street',
#     'The Harbourside Market'],
#    'best_route_names': ['The corn exchange',
#     "Brunel's SS Great Britain",
#     'Avon Gorge'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.4784601950225586},
#   {'user_id': '139879813@N08',
#    'route_index': 34,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 166,
#    'optimum_walking_time': '30',
#    'is_legal_dict': {45: 1, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['The Bearpit',
#     'Nelson Street',
#     'Tobacco Factory',
#     'Underfall Yard',
#     'The Centre, Bristol'],
#    'best_route_names': ['The Bearpit',
#     "Brunel's SS Great Britain",
#     'Bristol Zoo Gardens'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 0.7493167324627998}],
#  '45': [{'user_id': '79189348@N00',
#    'route_index': 54,
#    'file_name': 'opennes_only',
#    'total_num_of_tree_nodes': 234,
#    'optimum_walking_time': '45',
#    'is_legal_dict': {45: 0, 30: 0, 20: 0, 15: 0, 10: 0, 5: 0},
#    'user_route_names': ['Blaise Castle Estate',
#     'St Andrews Park',
#     'Clifton Observatory',
#     'Avon Gorge',
#     'The Clifton Suspension Bridge',
#     'Ashton Court Estate',
#     'Old Market Street',
#     'The Galleries',
#     'New Room',
#     'St Mary Redcliffe Church'],
#    'best_route_names': ['Blaise Castle Estate',
#     'Wild Place Project',
#     'Aerospace Bristol'],
#    'best_ndcg': 0.0,
#    'best_jaccard': 0.0,
#    'best_route_reward': 0.0,
#    'best_route_reward_time': 0.0,
#    'best_route_ranking': 0.0,
#    'best_route_ranking_time': 0.0,
#    'org_route_reward': 0.0,
#    'org_route_reward_time': 0.0,
#    'org_route_ranking': 1.0,
#    'org_route_ranking_time': 1.2345215759849906}]}

# %%
avg_ndcg_minu_dict={owd:{erf:None for erf in experiment_run_for} for owd in  optimum_walking_distances}
avg_jaccard_minu_dict={owd:{erf:None for erf in experiment_run_for} for owd in  optimum_walking_distances}

for erf in experiment_run_for:
    for owd in optimum_walking_distances: 
        avg_ndcg_minu_dict[owd][erf]= np.mean([line['best_ndcg'] for line in experiment_data[erf][owd]])
        avg_jaccard_minu_dict[owd][erf] = np.mean([line['best_jaccard'] for line in experiment_data[erf][owd]])

# %%
for owd_index,owd in enumerate(optimum_walking_distances): 
    
    fig = plt.figure(figsize=(6,5), dpi=200)
    left, bottom, width, height = 0.1, 0.3, 0.8, 0.6
    ax = fig.add_axes([left, bottom, width, height]) 

    width = 0.35   
    ticks = np.arange(len(avg_ndcg_minu_dict[owd]))    
    ax.bar(ticks, avg_ndcg_minu_dict[owd].values() , width, label='NDCG')
    ax.bar(ticks + width, avg_jaccard_minu_dict[owd].values(), width, align="center", label='Jaccard')

    ax.set_ylabel('Average')
    ax.set_title('Walking Distance '+owd +' Minutes')
    ax.set_xticks(ticks + width/2)
    ax.set_yticks(np.arange(0, 0.11, step=0.01))

    plt.xticks(rotation=90)
    ax.set_xticklabels([fn_p.replace('_', ' ').upper() for fn_p in avg_ndcg_minu_dict[owd].keys()])

    ax.legend(loc='best')
    plt.show()

# %% [markdown]
# # Average ndcg and jaccard for legal and illegal  routes

# %%
legal_avg_ndcg_minu_dict={owd:{erf:0.0 for erf in experiment_run_for} for owd in  optimum_walking_distances}
illegal_avg_ndcg_minu_dict = {owd:{erf:0.0 for erf in experiment_run_for} for owd in  optimum_walking_distances}

legal_avg_jaccard_minu_dict={owd:{erf:0.0 for erf in experiment_run_for} for owd in  optimum_walking_distances}
illegal_avg_jaccard_minu_dict={owd:{erf:0.0 for erf in experiment_run_for} for owd in  optimum_walking_distances}

for erf in experiment_run_for:
    for owd in optimum_walking_distances: 
        
        legal_ndcg=list()
        legal_jaccard=list()
        illegal_ndcg=list()
        illegal_jaccard=list()
        
        for line in experiment_data[erf][owd]:
            if line['is_legal_dict'][int(owd)]== 1:
                legal_ndcg.append(line['best_ndcg'])
                legal_jaccard.append(line['best_jaccard'])
            else:
                illegal_ndcg.append(line['best_ndcg'])
                illegal_jaccard.append(line['best_jaccard'])
        
        legal_avg_ndcg_minu_dict[owd][erf] = np.mean(legal_ndcg) if len(legal_ndcg) > 0 else 0.0
        legal_avg_jaccard_minu_dict[owd][erf] = np.mean(legal_jaccard) if len(legal_jaccard) > 0 else 0.0
        illegal_avg_ndcg_minu_dict[owd][erf] = np.mean(illegal_ndcg) if len(illegal_ndcg) > 0 else 0.0
        illegal_avg_jaccard_minu_dict[owd][erf] = np.mean(illegal_jaccard)  if len(illegal_jaccard) > 0 else 0.0

# %%
for owd_index,owd in enumerate(optimum_walking_distances): 

    fig = plt.figure(figsize=(6,5), dpi=200)
    left, bottom, width, height = 0.1, 0.3, 0.8, 0.6
    ax = fig.add_axes([left, bottom, width, height]) 

    width = 0.15  
    ticks = np.arange(len(avg_ndcg_minu_dict[owd])) 
    
    ax.bar(ticks - width, legal_avg_ndcg_minu_dict[owd].values(), width, label='legal NDCG', color=(0.2, 0.4, 0.6, 0.1))

    ax.bar(ticks, illegal_avg_ndcg_minu_dict[owd].values(), width, label='illegal NDCG', color=(0.2, 0.4, 0.6, 0.6))


    ax.bar(ticks+ width , legal_avg_jaccard_minu_dict[owd].values(), width, align="center", label='legal Jaccard', color=(0.2, 0.9, 0.6, 0.3))

    ax.bar(ticks + 2*width, illegal_avg_jaccard_minu_dict[owd].values(), width, align="center", label='illegal Jaccard', color=(0.2, 0.9, 0.6, 0.6))

    ax.set_ylabel('Average') 
    ax.set_xticks(ticks + width/2)
    ax.set_ylabel('Average')
    ax.set_title('Walking Distance '+owd +' Minutes')
    plt.xticks(rotation=90)
    ax.set_xticklabels([fn_p.replace('_', ' ').upper() for fn_p in avg_ndcg_minu_dict[owd].keys()])
    ax.set_yticks(np.arange(0, 0.3, step=0.05))

    ax.legend(loc='upper right', bbox_to_anchor=(0.7, 1.4))
    plt.show()
